# %% [markdown]
# # Temporal Train-Test Split

# %%
import pandas as pd
import numpy as np

from forecast_tools.datasets import load_emergency_dept

import numpy.typing as npt

# %%
def ts_train_test_split(ts: npt.ArrayLike, training_size: int):
    if isinstance(ts, pd.DataFrame):
        return ts.iloc[:training_size], ts.iloc[training_size:]

    return ts[:training_size], ts[training_size:]

# %%
ts_ed = load_emergency_dept()
ts_ed.head()
# Out:
# /home/tom/miniforge3/envs/ts/lib/python3.12/site-packages/forecast_tools/datasets.py:26: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(path, index_col='date', parse_dates=True,
#             arrivals
# date
# 2017-01-22       170
# 2017-01-23       196
# 2017-01-24       186
# 2017-01-25       200
# 2017-01-26       228

# %%
ts_ed.plot(figsize=(9,5))
# Out:
# <Axes: xlabel='date'>

# %%
# 28 day holdout
training_size = ts_ed.shape[0] - 28

train, test = ts_train_test_split(ts_ed, training_size=training_size)

# %%
train.shape
# Out:
# (316, 1)

# %%
test.shape
# Out:
# (28, 1)
